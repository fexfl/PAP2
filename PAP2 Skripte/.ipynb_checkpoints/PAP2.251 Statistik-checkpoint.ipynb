# %% [markdown]
# # Versuch 251 Statistik - Auswertung
# #### Felix Fleischle - 23.2.2022

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
#Zaehlrohrspannung:
U=np.array([450,475,500,525,550,575,600])
#U_err = np.array([10, 5, 5, 5, 5, 5, 5])
#gezaehlte Ereignisse
N=np.array([2496,2559,2498,2641,2501,2619,2630])
Fehler_N=np.sqrt(N)

# %%
plt.figure(figsize=(8, 6), dpi=80)
plt.errorbar(U, N, Fehler_N, fmt=".", label="N(V)",linestyle="none", capsize = 2)
plt.xlabel("Spannung / V")
plt.ylabel("Ereignissse")
plt.title("Zaehlrohrcharakteristik")
plt.legend()
plt.grid(linestyle=":", linewidth=1)

# %%
def linear(x,a,b):
    return a*x+b

popt, pcov=curve_fit(linear, U[1:], N[1:])

# %%
plt.figure(figsize=(8, 6), dpi=80)
plt.errorbar(U, N, Fehler_N, fmt=".", label="N(V)",linestyle="none", capsize = 2)
plt.xlabel("Spannung / V")
plt.ylabel("Ereignissse")
plt.title("Zaehlrohrcharakteristik")
plt.plot(U, linear(U,*popt), label="fit")
plt.legend()
plt.grid(linestyle=":", linewidth=1)
# error wegen zu hoher anfangspannung, weniger messpunkte

# %%
# 2. Plateaubereich
N_array_p = np.array([12658, 37394, 12750, 37752])
N_array_p_err = np.sqrt(N_array_p)
print(N_array_p_err)

t_array_p = np.array([60, 180, 60, 180])

n_array_p = N_array_p / t_array_p
n_array_p_err = N_array_p_err / t_array_p

print("Zählraten:", n_array_p, "+-", n_array_p_err)
# Out:
# [112.50777751 193.37528281 112.91589791 194.29873906]
# Zählraten: [210.96666667 207.74444444 212.5        209.73333333] +- [1.87512963 1.07430713 1.88193163 1.07943744]

# %%
# Plateauanstiege:
a_1m = n_array_p[2]-n_array_p[0]
a_1m_err = np.sqrt(n_array_p_err[2]**2 + n_array_p_err[0]**2)

a_3m = n_array_p[3]-n_array_p[1]
a_3m_err = np.sqrt(n_array_p_err[3]**2 + n_array_p_err[1]**2)

print("Plateauanstieg 1m:", a_1m, "+-", a_1m_err, "[1/s]")
print("Plateauanstieg 3m:", a_3m, "+-", a_3m_err, "[1/s]")
# Out:
# Plateauanstieg 1m: 1.5333333333333314 +- 2.6566478460228367 [1/s]
# Plateauanstieg 3m: 1.98888888888888 +- 1.5229317081387206 [1/s]

# %%
# Prozentuale Anstiege:
a_proz_1m = a_1m / n_array_p[0]
a_proz_1m_err = np.sqrt((a_1m_err / n_array_p[0])**2 + (a_1m * n_array_p_err[0] / (n_array_p[0])**2)**2)

a_proz_3m = a_3m / n_array_p[1]
a_proz_3m_err = np.sqrt((a_3m_err / n_array_p[1])**2 + (a_3m * n_array_p_err[1] / (n_array_p[1])**2)**2)

print("Prozentualer Anstieg 1m:", a_proz_1m, "+-", a_proz_1m_err)
print("Prozentualer Anstieg 3m:", a_proz_3m, "+-", a_proz_3m_err)
# Out:
# Prozentualer Anstieg 1m: 0.007268130826354865 +- 0.012592903161280705
# Prozentualer Anstieg 3m: 0.009573728405626529 +- 0.007330961086002894

# %%
# Prüfe Signifikanz
sigma_1m = a_1m / a_1m_err
sigma_3m = a_3m / a_3m_err

#sigma_proz_1m = a_proz_1m / a_proz_1m_err
#sigma_proz_3m = a_proz_3m / a_proz_3m_err

print("Abweichungen:", sigma_1m, sigma_3m)
# Out:
# Abweichungen: 0.5771684552127693 1.3059606535605184 0.5771608606268114 1.305930872270729

# %%
# Zeit für 99% Genauigkeit
t_001 = (n_array_p[2]+n_array_p[0])/(0.01**2 *(n_array_p[2]-n_array_p[0])**2)
print(t_001)
t_003 = (n_array_p[3]+n_array_p[1])/(0.01**2 *(n_array_p[3]-n_array_p[1])**2)
print(t_003)

t_0011 = 1/(n_array_p[2]-n_array_p[0])/(0.01**2 * n_array_p[2]**2 * n_array_p[0]**2)
print(t_0011)
# Out:
# 1801134.2155009499
# 1055388.4086014887
# 3.2450236950837215e-06

# %%
# Prozentuale Variation für Vertrauensniveau:
#68%
a_proz_max_68_1m = a_proz_1m + a_proz_1m_err
a_proz_max_68_3m = a_proz_3m + a_proz_3m_err
print("Prozentuale Variation für 68%:", a_proz_max_68_1m, a_proz_max_68_3m)

#95%
a_proz_max_95_1m = a_proz_1m + 2*a_proz_1m_err
a_proz_max_95_3m = a_proz_3m + 2*a_proz_3m_err
print("Prozentuale Variation für 95%:", a_proz_max_95_1m, a_proz_max_95_3m)
# Out:
# Prozentuale Variation für 68%: 0.01986103398763557 0.01690468949162942
# Prozentuale Variation für 95%: 0.03245393714891628 0.024235650577632314

# %%
anzahl, haeufigkeit=np.loadtxt("C:/Users/fexfl/Documents/.Keine Programme Docs/Studium/PAP2/251/ff251.dat", unpack=True)
fehler=np.sqrt(haeufigkeit)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-9fc600fd285c> in <module>
# ----> 1 anzahl, haeufigkeit=np.loadtxt("C:/Users/fexfl/Documents/.Keine Programme Docs/Studium/PAP2/251/ff251.dat", unpack=True)
#       2 fehler=np.sqrt(haeufigkeit)
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1063             fname = os_fspath(fname)
#    1064         if _is_string_like(fname):
# -> 1065             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1066             fencoding = getattr(fh, 'encoding', 'latin1')
#    1067             fh = iter(fh)
#
# ~\anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     192
#     193     ds = DataSource(destpath)
# --> 194     return ds.open(path, mode, encoding=encoding, newline=newline)
#     195
#     196
#
# ~\anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(self, path, mode, encoding, newline)
#     529                                       encoding=encoding, newline=newline)
#     530         else:
# --> 531             raise IOError("%s not found." % path)
#     532
#     533
#
# OSError: C:/Users/fexfl/Documents/.Keine Programme Docs/Studium/PAP2/251/ff251.dat not found.

# %%
plt.figure(figsize=(8, 6), dpi=80)
plt.errorbar(anzahl, haeufigkeit, fehler, fmt=".", label="Messung",linestyle="none", capsize = 2)
plt.xlabel("Anzahl der Zerfaelle pro Zeiteinheit / 1/s ")
plt.ylabel("Haeufigkeit")
plt.title("Statistik des radioaktiven Zerfalls")
plt.legend()
plt.grid(linestyle=":", linewidth=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-2315b59a7e4c> in <module>
#       1 plt.figure(figsize=(8, 6), dpi=80)
# ----> 2 plt.errorbar(anzahl, haeufigkeit, fehler, fmt=".", label="Messung",linestyle="none", capsize = 2)
#       3 plt.xlabel("Anzahl der Zerfaelle pro Zeiteinheit / 1/s ")
#       4 plt.ylabel("Haeufigkeit")
#       5 plt.title("Statistik des radioaktiven Zerfalls")
#
# NameError: name 'anzahl' is not defined

# %%
from numpy import exp, pi, sqrt
def gaussian(x, A, mu, sig): #A: Flaeche der Gaussfunktion
    return A/(sqrt(2*pi)*sig)*exp(-(x-mu)**2/2/sig**2)

# %%
popt, pcov=curve_fit(gaussian,anzahl[7:-15], haeufigkeit[7:-15], p0=[2000,71.802,8.304],sigma=fehler[7:-15])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7b60e3b16626> in <module>
# ----> 1 popt, pcov=curve_fit(gaussian,anzahl[7:-15], haeufigkeit[7:-15], p0=[2000,71.802,8.304],sigma=fehler[7:-15])
#
# NameError: name 'anzahl' is not defined

# %%
from scipy.special import gamma
def poisson(x, A_p, mu_p):
    return A_p*exp(-mu_p)*mu_p**x/gamma(x+1)

popt_p, pcov_p = curve_fit(poisson, anzahl[7:-15], haeufigkeit[7:-15], p0=[2000, 71.802], sigma=fehler[7:-15])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f3eac0e652ba> in <module>
#       3     return A_p*exp(-mu_p)*mu_p**x/gamma(x+1)
#       4
# ----> 5 popt_p, pcov_p = curve_fit(poisson, anzahl[7:-15], haeufigkeit[7:-15], p0=[2000, 71.802], sigma=fehler[7:-15])
#
# NameError: name 'anzahl' is not defined

# %%
plt.figure(figsize=(8, 6), dpi=80)
plt.errorbar(anzahl,haeufigkeit,fehler, fmt=".",label="Messung")
plt.xlabel("Anzahl der Zerfaelle pro Zeiteinheit 1/s ")
plt.ylabel("Haeufigkeit")
plt.title("Statistik des radioaktiven Zerfalls")
x=np.linspace(40,110, 100)
plt.plot(x, gaussian(x,*popt), label="Gauss")
plt.plot(x, poisson(x,*popt_p), label="Poisson",linestyle=":")
plt.legend()
plt.grid(linestyle=":", linewidth=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-9d5ea0a0f7e0> in <module>
#       1 plt.figure(figsize=(8, 6), dpi=80)
# ----> 2 plt.errorbar(anzahl,haeufigkeit,fehler, fmt=".",label="Messung")
#       3 plt.xlabel("Anzahl der Zerfaelle pro Zeiteinheit 1/s ")
#       4 plt.ylabel("Haeufigkeit")
#       5 plt.title("Statistik des radioaktiven Zerfalls")
#
# NameError: name 'anzahl' is not defined

# %%
print("Gaussfit:")
print("A=",popt[0], ", Standardfehler=", np.sqrt(pcov[0][0]))
print("mu=",popt[1], ", Standardfehler=", np.sqrt(pcov[1][1]))
print("sig=",popt[2], ", Standardfehler=", np.sqrt(pcov[2][2]))
print("Poissonfit:")
print("A_p=",popt_p[0], ", Standardfehler=", sqrt(pcov_p[0][0]))
print("mu_p=",popt_p[1], ", Standardfehler=", sqrt(pcov_p[1][1]))
# Out:
# Gaussfit:
# A= 0.6605715111986967 , Standardfehler= 0.6085994502247634
# mu= 2219.6094793973684 , Standardfehler= 328.152597120166
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-4fa0bc19b255> in <module>
#       2 print("A=",popt[0], ", Standardfehler=", np.sqrt(pcov[0][0]))
#       3 print("mu=",popt[1], ", Standardfehler=", np.sqrt(pcov[1][1]))
# ----> 4 print("sig=",popt[2], ", Standardfehler=", np.sqrt(pcov[2][2]))
#       5 print("Poissonfit:")
#       6 print("A_p=",popt_p[0], ", Standardfehler=", sqrt(pcov_p[0][0]))
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
#Gauss:
chi2_g=np.sum((gaussian(anzahl[7:-15],*popt)
-haeufigkeit[7:-15])**2/fehler[7:-15]**2)
dof_g=len(anzahl[7:-15])-3 #dof:degrees of freedom, Freiheitsgrad
chi2_red_g=chi2_g/dof_g
print("chi2_g=", chi2_g)
print("chi2_red_g=",chi2_red_g)
#Poisson:
chi2_p=np.sum((poisson(anzahl[7:-15],*popt_p)
-haeufigkeit[7:-15])**2/fehler[7:-15]**2)
dof_p=len(anzahl[7:-15])-2 #poisson hat nur 2 Parameter
chi2_red_p=chi2_p/dof_p
print("chi2_p=", chi2_p)
print("chi2_red_p=",chi2_red_p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-410f015a03bd> in <module>
#       1 #Gauss:
# ----> 2 chi2_g=np.sum((gaussian(anzahl[7:-15],*popt)
#       3 -haeufigkeit[7:-15])**2/fehler[7:-15]**2)
#       4 dof_g=len(anzahl[7:-15])-3 #dof:degrees of freedom, Freiheitsgrad
#       5 chi2_red_g=chi2_g/dof_g
#
# NameError: name 'anzahl' is not defined

# %%
from scipy.stats import chi2
#Gauss:
prob_g=round(1-chi2.cdf(chi2_g,dof_g),2)*100
#Poisson:
prob_p=round(1-chi2.cdf(chi2_p,dof_p),2)*100
print("Wahrscheinlichkeit Gauss=", prob_g,"%")
print("Wahrscheinlichkeit Poisson=", prob_p,"%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9441c108a096> in <module>
#       1 from scipy.stats import chi2
#       2 #Gauss:
# ----> 3 prob_g=round(1-chi2.cdf(chi2_g,dof_g),2)*100
#       4 #Poisson:
#       5 prob_p=round(1-chi2.cdf(chi2_p,dof_p),2)*100
#
# NameError: name 'chi2_g' is not defined

# %%
anzahl2, haeufigkeit2=np.loadtxt("C:/Users/fexfl/Documents/.Keine Programme Docs/Studium/PAP2/251/ff251p.dat", unpack=True)
fehler2=np.sqrt(haeufigkeit2)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-3d90539895a6> in <module>
# ----> 1 anzahl2, haeufigkeit2=np.loadtxt("C:/Users/fexfl/Documents/.Keine Programme Docs/Studium/PAP2/251/ff251p.dat", unpack=True)
#       2 fehler2=np.sqrt(haeufigkeit2)
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1063             fname = os_fspath(fname)
#    1064         if _is_string_like(fname):
# -> 1065             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1066             fencoding = getattr(fh, 'encoding', 'latin1')
#    1067             fh = iter(fh)
#
# ~\anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     192
#     193     ds = DataSource(destpath)
# --> 194     return ds.open(path, mode, encoding=encoding, newline=newline)
#     195
#     196
#
# ~\anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(self, path, mode, encoding, newline)
#     529                                       encoding=encoding, newline=newline)
#     530         else:
# --> 531             raise IOError("%s not found." % path)
#     532
#     533
#
# OSError: C:/Users/fexfl/Documents/.Keine Programme Docs/Studium/PAP2/251/ff251p.dat not found.

# %%
plt.figure(figsize=(8, 6), dpi=80)
plt.errorbar(anzahl2, haeufigkeit2, fehler2, fmt=".", label="Messung",linestyle="none", capsize = 2)
plt.xlabel("Anzahl der Zerfaelle pro Zeiteinheit / 1/s ")
plt.ylabel("Haeufigkeit")
plt.title("Statistik des radioaktiven Zerfalls")
plt.legend()
plt.grid(linestyle=":", linewidth=1)
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-1b7c9a5dc588> in <module>
#       1 plt.figure(figsize=(8, 6), dpi=80)
# ----> 2 plt.errorbar(anzahl2, haeufigkeit2, fehler2, fmt=".", label="Messung",linestyle="none", capsize = 2)
#       3 plt.xlabel("Anzahl der Zerfaelle pro Zeiteinheit / 1/s ")
#       4 plt.ylabel("Haeufigkeit")
#       5 plt.title("Statistik des radioaktiven Zerfalls")
#
# NameError: name 'anzahl2' is not defined

# %%
popt2, pcov2=curve_fit(gaussian,anzahl2, haeufigkeit2, p0=[2000,4.3627,2.1066],sigma=fehler2)
popt_p2, pcov_p2 = curve_fit(poisson, anzahl2, haeufigkeit2, p0=[2000, 4.3627], sigma=fehler2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-7f617d6600cd> in <module>
# ----> 1 popt2, pcov2=curve_fit(gaussian,anzahl2, haeufigkeit2, p0=[2000,4.3627,2.1066],sigma=fehler2)
#       2 popt_p2, pcov_p2 = curve_fit(poisson, anzahl2, haeufigkeit2, p0=[2000, 4.3627], sigma=fehler2)
#
# NameError: name 'anzahl2' is not defined

# %%
plt.figure(figsize=(8, 6), dpi=80)
plt.errorbar(anzahl2,haeufigkeit2,fehler2, fmt=".",label="Messung")
plt.xlabel("Anzahl der Zerfaelle pro Zeiteinheit 1/s ")
plt.ylabel("Haeufigkeit")
plt.title("Statistik des radioaktiven Zerfalls")
x2=np.linspace(0,14, 100)
plt.plot(x2, gaussian(x2,*popt2), label="Gauss")
plt.plot(x2, poisson(x2,*popt_p2), label="Poisson",linestyle=":")
plt.legend()
plt.grid(linestyle=":", linewidth=1)
plt.yscale("log")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-db726e021b38> in <module>
#       1 plt.figure(figsize=(8, 6), dpi=80)
# ----> 2 plt.errorbar(anzahl2,haeufigkeit2,fehler2, fmt=".",label="Messung")
#       3 plt.xlabel("Anzahl der Zerfaelle pro Zeiteinheit 1/s ")
#       4 plt.ylabel("Haeufigkeit")
#       5 plt.title("Statistik des radioaktiven Zerfalls")
#
# NameError: name 'anzahl2' is not defined

# %%
print("Gaussfit:")
print("A=",popt2[0], ", Standardfehler=", np.sqrt(pcov2[0][0]))
print("mu=",popt2[1], ", Standardfehler=", np.sqrt(pcov2[1][1]))
print("sig=",popt2[2], ", Standardfehler=", np.sqrt(pcov2[2][2]))
print("Poissonfit:")
print("A_p=",popt_p2[0], ", Standardfehler=", sqrt(pcov_p2[0][0]))
print("mu_p=",popt_p2[1], ", Standardfehler=", sqrt(pcov_p2[1][1]))
# Out:
# Gaussfit:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6d7e443e2d15> in <module>
#       1 print("Gaussfit:")
# ----> 2 print("A=",popt2[0], ", Standardfehler=", np.sqrt(pcov2[0][0]))
#       3 print("mu=",popt2[1], ", Standardfehler=", np.sqrt(pcov2[1][1]))
#       4 print("sig=",popt2[2], ", Standardfehler=", np.sqrt(pcov2[2][2]))
#       5 print("Poissonfit:")
#
# NameError: name 'popt2' is not defined

# %%
#Gauss:
chi2_g2=np.sum((gaussian(anzahl2,*popt2)
-haeufigkeit2)**2/fehler2**2)
dof_g2=len(anzahl2)-3 #dof:degrees of freedom, Freiheitsgrad
chi2_red_g2=chi2_g2/dof_g2
print("chi2_g=", chi2_g2)
print("chi2_red_g=",chi2_red_g2)
#Poisson:
chi2_p2=np.sum((poisson(anzahl2,*popt_p2)
-haeufigkeit2)**2/fehler2**2)
dof_p2=len(anzahl2)-2 #poisson hat nur 2 Parameter
chi2_red_p2=chi2_p2/dof_p2
print("chi2_p=", chi2_p2)
print("chi2_red_p=",chi2_red_p2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-e2664fc1b738> in <module>
#       1 #Gauss:
# ----> 2 chi2_g2=np.sum((gaussian(anzahl2,*popt2)
#       3 -haeufigkeit2)**2/fehler2**2)
#       4 dof_g2=len(anzahl2)-3 #dof:degrees of freedom, Freiheitsgrad
#       5 chi2_red_g2=chi2_g2/dof_g2
#
# NameError: name 'anzahl2' is not defined

# %%
#Gauss:
prob_g2=round(1-chi2.cdf(chi2_g2,dof_g2),2)*100
#Poisson:
prob_p2=round(1-chi2.cdf(chi2_p2,dof_p2),2)*100
print("Wahrscheinlichkeit Gauss=", prob_g2,"%")
print("Wahrscheinlichkeit Poisson=", prob_p2,"%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-c758e4d40e62> in <module>
#       1 #Gauss:
# ----> 2 prob_g2=round(1-chi2.cdf(chi2_g2,dof_g2),2)*100
#       3 #Poisson:
#       4 prob_p2=round(1-chi2.cdf(chi2_p2,dof_p2),2)*100
#       5 print("Wahrscheinlichkeit Gauss=", prob_g2,"%")
#
# NameError: name 'chi2_g2' is not defined
